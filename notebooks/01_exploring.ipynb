# %% [markdown]
# # Check all datasets

# %%
display(dbutils.fs.ls("/databricks-datasets"))

# %% [markdown]
# # Choose a dataset

# %% [markdown]
# # Read csv data and write into a dataframe

# %%
file_path = "/databricks-datasets/bikeSharing/data-001/hour.csv"

df_raw = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load(file_path)

# %% [markdown]
# # show dataframe

# %%
display(df_raw)
print(df_raw.count())

# %%
df_raw.show(10)

# %%
df_raw.printSchema()

# %%
df_raw.select('holiday').distinct().show()

# %% [markdown]
# # Write data
#
# - Many things don't work because of the Free Edition of Databricks!
# - createOrReplaceTempView is the current but not persistent solution.
#
# A better solution needs to be found!

# %%
# 1. Pfad zu den Rohdaten (Die existieren ja schon, das ist erlaubt)
file_path = "/databricks-datasets/bikeSharing/data-001/hour.csv"

# 2. Laden in DataFrame
df_raw = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load(file_path)

# 3. STATT SPEICHERN: Wir erstellen eine temporäre SQL-Sicht
# Das macht die Tabelle für SQL verfügbar, solange der Cluster läuft.
df_raw.createOrReplaceTempView("bronze_trips")

print("Erfolg! Tabelle 'bronze_trips' ist jetzt per SQL abfragbar.")

# %%
# %sql
SELECT * FROM bronze_trips LIMIT 5
